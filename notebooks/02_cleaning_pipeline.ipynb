# %%
import sys
from pathlib import Path

#Path.cwd().parent depends on where you run this code from
#Path(__file__).resolve().parents[1] depends on where this file is located on disk
#
#project_root = .../1099-reconciliation-pipeline if notebook runs from the repo root or from notebooks/
cwd = Path.cwd()
project_root = cwd if (cwd / "src").exists() else cwd.parent # running from notebooks/  folder (cwd = current working directory) - .parent gets us to the folder above
sys.path.append(str(project_root)) #sys.path is a list of folders where python looks for modules
                                    # we add the project root to that list with .append

print("Project root: ", project_root)
# Out:
# /Users/manuelreyes/Desktop/dev/1099_reconciliation_pipeline

# %% [markdown]
# '--------------------------------  Test Cleaned DataFrame  --------------------------------'

# %% [markdown]
# '-----------------------  Relius Test  -----------------------'

# %%
from src import load_data
from src.clean_relius import clean_relius
from src.config import RAW_DATA_DIR

relius_path = RAW_DATA_DIR / "real_inherited_relius_2025.xlsx"

relius_raw = load_data.load_relius_excel(path=relius_path, use_sample_if_none=False)
relius_clean = clean_relius(relius_raw)

# .shape is an attribute of pandas DataFrames that returns a tuple of
# (number of rows, number of columns) - e.g. (1000, 15)
relius_raw.shape, relius_clean.shape
# Out:
# ((253, 374), (189, 12))

# %% [markdown]
# Notes:
# - Before cleaning process:
#     - 253 rows, after cleaning process 189, removing rows without key information and duplicates.
#     - 374 columns, after cleaning process 12, just the core columns we need for our matching and correction file
# - After cleaning process all columns were renamed  and values normalized to keep the same format between Relius and Matrix, see below:

# %%
# Review cleaned and normalized Relius data (top 5 rows by default)
relius_clean.head()
# Out:
#      plan_id        ssn first_name last_name state  gross_amt exported_date  \
# 0  300004MBD  194420270      David    Symons    PA    3347.62    2025-06-11
# 1  300004MBD  197323440      James   McNamee    PA   12623.05    2025-06-11
# 2  300004MBD  194420270      David    Symons    PA    2652.38    2025-06-13
# 4  300004MBD  197526965      David      Kich    PA    3000.00    2025-06-17
# 6  300004MBD  197526965      David      Kich    PA    3000.00    2025-07-03
#
#    tax_year dist_code_1                      dist_name dist_category_relius  \
# 0         0           4                        RMD ACH                  rmd
# 1         0           4                        RMD ACH                  rmd
# 2         0           4  Partial Liquidation Gross ACH         partial_cash
# 4         0           4  Partial Liquidation Gross ACH         partial_cash
# 6         0           4                  Recurring ACH         partial_cash
#
#        full_name
# 0   David Symons
# 1  James McNamee
# 2   David Symons
# 4     David Kich
# 6     David Kich

# %%
# .value_counts() returns a Series containing the counts of unique elements. In descending order
# Will show up to 20 rows .head(20)
relius_clean["dist_name"].value_counts().head(20)
# Out:
# dist_name
# Recurring ACH                     90
# Partial Liquidation Net ACH       27
# RMD ACH                           19
# Recurring Check Net               15
# Partial Liquidation Gross ACH     13
# RMD Check Net                      8
# RMD Check Gross                    4
# Partial Liquidation  Net Check     4
# Rollover                           3
# Partial Liquidate  Gross Check     3
# Full Liquidation                   2
# Partial Rollover - Net             1
# Name: count, dtype: int64

# %%
relius_clean["dist_category_relius"].value_counts()
# Out:
# dist_category_relius
# partial_cash        152
# rmd                  31
# rollover              3
# final_cash            2
# partial_rollover      1
# Name: count, dtype: int64

# %% [markdown]
# Notes:
# - From the values in "dist_name" we can group them in certain categories to establish different process flows for each category type.
#     - See above the categories after a new Series has been implemented.

# %% [markdown]
# '-----------------------  Matrix Test  -----------------------'

# %%
from src.clean_matrix import clean_matrix

matrix_path = RAW_DATA_DIR / "real_all_matrix_2025.xlsx"

matrix_raw = load_data.load_matrix_excel(path=matrix_path, use_sample_if_none=False)
matrix_clean = clean_matrix(matrix_raw)

# .shape is an attribute of pandas DataFrames that returns a tuple of
# (number of rows, number of columns) - e.g. (1000, 15)
matrix_raw.shape, matrix_clean.shape
# Out:
# /Users/manuelreyes/Desktop/dev/1099_reconciliation_pipeline/src/clean_matrix.py:181: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   return pd.to_datetime(series, errors="coerce").dt.date
# ((60972, 56), (6980, 16))

# %% [markdown]
# Notes:
# - Before cleaning process:
#     - 60,972 ROWS, after cleaning process 6,980, mostly removing rows that we don't need for our matching process (other Matrix acct types, transaction types, etc.).
#     - 56 columns, after cleaning process 14, just the core columns we need for our matching and correction file
# - After cleaning process all columns were renamed  and values normalized to keep the same format between Relius and Matrix, see below:

# %%
# Review cleaned and normalized Matrix data (top 5 rows by default)
matrix_clean.head(10)
# Out:
#           plan_id        ssn participant_name state  gross_amt  \
# 29932  IRA127PLAT  194362032     Sandra Marsh    PA     153.22
# 29933  IRA127PLAT  209501562  Kathryn Clausen    PA     200.00
# 29934  IRA127PLAT  194362032     Sandra Marsh    PA     153.22
# 29936  IRA127PLAT  209501562  Kathryn Clausen    PA     200.00
# 29938  IRA127PLAT  194362032     Sandra Marsh    PA     153.22
# 29939  IRA127PLAT  209501562  Kathryn Clausen    PA     200.00
# 29941  IRA127PLAT  194362032     Sandra Marsh    PA     153.22
# 29942  IRA127PLAT  209501562  Kathryn Clausen    PA     200.00
# 29944  IRA127PLAT  194362032     Sandra Marsh    PA     153.22
# 29945  IRA127PLAT  209501562  Kathryn Clausen    PA     200.00
#
#        fed_taxable_amt    txn_date        txn_method tax_code_1 tax_code_2  \
# 29932           153.22  2025-11-04  ACH Distribution          7       <NA>
# 29933           200.00  2025-11-04  ACH Distribution          7       <NA>
# 29934           153.22  2025-10-16  ACH Distribution          7       <NA>
# 29936           200.00  2025-10-03  ACH Distribution          7       <NA>
# 29938           153.22  2025-09-03  ACH Distribution          7       <NA>
# 29939           200.00  2025-09-03  ACH Distribution          7       <NA>
# 29941           153.22  2025-08-05  ACH Distribution          7       <NA>
# 29942           200.00  2025-08-05  ACH Distribution          7       <NA>
# 29944           153.22  2025-07-03  ACH Distribution          7       <NA>
# 29945           200.00  2025-07-03  ACH Distribution          7       <NA>
#
#       tax_form dist_type  roth_initial_contribution_year transaction_id  \
# 29932   1099-R       nan                            <NA>       44178108
# 29933   1099-R       nan                            <NA>       44178107
# 29934   1099-R       nan                            <NA>       43696486
# 29936   1099-R       nan                            <NA>       43237695
# 29938   1099-R       nan                            <NA>       42348013
# 29939   1099-R       nan                            <NA>       42348012
# 29941   1099-R       nan                            <NA>       41521055
# 29942   1099-R       nan                            <NA>       41521056
# 29944   1099-R       nan                            <NA>       40587387
# 29945   1099-R       nan                            <NA>       40587386
#
#       matrix_account   partipant_name
# 29932       07P6LM3M     Sandra Marsh
# 29933       07P6LM3M  Kathryn Clausen
# 29934       07P6LM3M     Sandra Marsh
# 29936       07P6LM3M  Kathryn Clausen
# 29938       07P6LM3M     Sandra Marsh
# 29939       07P6LM3M  Kathryn Clausen
# 29941       07P6LM3M     Sandra Marsh
# 29942       07P6LM3M  Kathryn Clausen
# 29944       07P6LM3M     Sandra Marsh
# 29945       07P6LM3M  Kathryn Clausen

# %% [markdown]
# Notes:
# - After running the DataFrame for the first time: SSN was 10 digits and tax_code_1 was '7NORMALDISTRIBUTION' instead of just '7' or 'G'
# - These fields were not rendered correctly (using logic from clean_relius module), and some additional logic were needed:
#     - Matrix SSN value is being read as a float in Excel so a 111223344 SSN was stored as 111223344.0 in our raw DataFrame giving 1112233440
#         - 1) implemented str convertion from Float
#         - 2) extract the first 9 digits (safe since SSNs are always 9 digits)
#     - Matrix Tax code values are '7 - Normal Distribution' or 'G - Rollover' so a different logic was applied than clean_relius using REGEX:
#         - 1) remove any 'CODE'/'code' before the code digit, e.g. 'CODE' 7.
#         - 2) grab the alphanumerical digits next '7' or 'G'.
#         - 3) extract the first digit (safe since the tax code is always 1 digit)
#     - Matrix transaction_id is also being read as a float in Excel so were getting an extra digit that needed to be removed
#         - 1) implemented str convertion from Float '44556677.0'
#         - 2) extract all non-numerical characters '.' -> '445566770'
#         - 3) extract all numerical characters until the last '0' -> '44556677'

# %%
# Experiments with re.search() and .group() to solve transaction_id normalization
import re

value = float(12345.0)

text = str(value).strip()

text = re.sub(r"\D", "", text)

m = re.search(r"(\d+)0$", text)

# .group() return full match or sub groups (from parenthesis)

#m.group(0) -> '123450'
m.group(1) #-> correct: '12345'
#m.group(2) -> 'Error: no such group'
# Out:
# '12345'

# %% [markdown]
# Research:
# - Needed to strengthen my knowledge in regex with re.search and .group():
#     - Example: extract parts of '12345-ABCD'
#         1) m = re.search(r"(\d+)-([A-Z]+), "12345-ABCD")
#         2) m.group(0) -> "12345-ABCD"
#         3) m.group(1) -> "12345"
#         4) m.group(2) -> "ABCD"
#     - Parenthesis are what define groups.

# %%
# Check tax_code_1 to see format
matrix_clean["tax_code_1"].value_counts()
# Out:
# tax_code_1
# 7     5087
# G      833
# 2      309
# 11     265
# B      140
# 1      122
# 4       94
# H       93
# 15      10
# 17       6
# 16       3
# 3        2
# 13       2
# 18       2
# 33       1
# D        1
# Name: count, dtype: int64

# %% [markdown]
# Notes:
# - After logic was updated tax_code_1 was normalized correctly, so it shows the exact codes we need.

# %%
# Check that unwanted accounts are gone
matrix_clean["matrix_account"].value_counts().head(20)
# Out:
# matrix_account
# 07P6LM97    455
# 07P6LM4K    386
# 07P6LM4C    126
# 07P6LM3T    124
# 07P6LM6D    104
# 07P6LM49    102
# 07P6LM5G     95
# 07P6LM3X     87
# 07P6LMC7     78
# 07P6LM9R     75
# 07P6LNYW     69
# 07P6LM45     69
# 07P6LM54     65
# 07P6LM65     55
# 07P6LM46     42
# 07P6LM6P     42
# 07P6LM9V     41
# 07P6LM9M     39
# 07P6LM5D     38
# 07P6LM3Z     38
# Name: count, dtype: int64

# %% [markdown]
# Notes:
# - Verified: After cleaned DataFrame not showing matrix_account we don't need in our matching and correction process.

# %%
# Check that unwanted txn types are gone
matrix_clean["txn_method"].value_counts().head(20)
# Out:
# txn_method
# ACH Distribution      5450
# Check Distribution    1421
# Tax Record Only         56
# Check Reissue           36
# Wire Distribution       17
# Name: count, dtype: int64

# %% [markdown]
# Notes:
# - Verified: After cleaned DataFrame not showing 'txn_method' we don't need in our matching and correction process.

# %%
matrix_clean[["fed_taxable_amt", "roth_initial_contribution_year"]].head()
# Out:
#        fed_taxable_amt  roth_initial_contribution_year
# 29932           153.22                            <NA>
# 29933           200.00                            <NA>
# 29934           153.22                            <NA>
# 29936           200.00                            <NA>
# 29938           153.22                            <NA>

# %% [markdown]
# Notes:
# - Verified: After cleaned DataFrame we show new columns 'fed_taxable_amt' and 'roth_initial_contribution_year' succesfully

# %%
matrix_clean.dtypes[["fed_taxable_amt", "roth_initial_contribution_year"]]
# Out:
# fed_taxable_amt                   float64
# roth_initial_contribution_year      Int64
# dtype: object

# %% [markdown]
# Notes:
# - Verified: Normalization works well for new columns added to DataFrame from raw Excel file.

# %% [markdown]
# Notes:
# - Verified: After cleaned DataFrame not showing txn_method we don't need in our matching and correction process.

# %% [markdown]
# '--------------------------------  Experiments  --------------------------------'

# %% [markdown]
# '-----------------------  Drop Columns  -----------------------'

# %% [markdown]
# We used df.dropna(subsett=["list of columns"], how="any") to:
# - Drop rows where 'any' column have NA
# - We also can drop rows only where 'all' columns have NaN, using how='all'
# - By default .dropna(axis=0) to drop rows, what about to drop columns:
#     - we can change axis to df.dropna(axis=1, how="all") -> drop columns that are all NaN
#
# - When using .drop_duplicates(), doesn't have an axis parameter. It alwas works on rows.
#     - We can use a use the function transpose (T) to switch rows to columns and rows to columns

# %%
# Use transpose to switch columns to rows (and rows to columns)
t_matrix_clean = matrix_clean.T

t_matrix_clean.head(10)
# Out:
#                              29932             29933             29934  \
# plan_id                 IRA127PLAT        IRA127PLAT        IRA127PLAT
# ssn                      194362032         209501562         194362032
# participant_name      Sandra Marsh   Kathryn Clausen      Sandra Marsh
# state                           PA                PA                PA
# gross_amt                   153.22             200.0            153.22
# fed_taxable_amt             153.22             200.0            153.22
# txn_date                2025-11-04        2025-11-04        2025-10-16
# txn_method        ACH Distribution  ACH Distribution  ACH Distribution
# tax_code_1                       7                 7                 7
# tax_code_2                    <NA>              <NA>              <NA>
#
#                              29936             29938             29939  \
# plan_id                 IRA127PLAT        IRA127PLAT        IRA127PLAT
# ssn                      209501562         194362032         209501562
# participant_name   Kathryn Clausen      Sandra Marsh   Kathryn Clausen
# state                           PA                PA                PA
# gross_amt                    200.0            153.22             200.0
# fed_taxable_amt              200.0            153.22             200.0
# txn_date                2025-10-03        2025-09-03        2025-09-03
# txn_method        ACH Distribution  ACH Distribution  ACH Distribution
# tax_code_1                       7                 7                 7
# tax_code_2                    <NA>              <NA>              <NA>
#
#                              29941             29942             29944  \
# plan_id                 IRA127PLAT        IRA127PLAT        IRA127PLAT
# ssn                      194362032         209501562         194362032
# participant_name      Sandra Marsh   Kathryn Clausen      Sandra Marsh
# state                           PA                PA                PA
# gross_amt                   153.22             200.0            153.22
# fed_taxable_amt             153.22             200.0            153.22
# txn_date                2025-08-05        2025-08-05        2025-07-03
# txn_method        ACH Distribution  ACH Distribution  ACH Distribution
# tax_code_1                       7                 7                 7
# tax_code_2                    <NA>              <NA>              <NA>
#
#                              29945  ...             60755          60763  \
# plan_id                 IRA127PLAT  ...            88PLAT       219MBDII
# ssn                      209501562  ...         816006350      170662072
# participant_name   Kathryn Clausen  ...   David Portelles   Megan Garner
# state                           PA  ...                PA             PA
# gross_amt                    200.0  ...           12500.0         5000.0
# fed_taxable_amt              200.0  ...           12500.0            0.0
# txn_date                2025-07-03  ...        2025-08-15     2025-07-29
# txn_method        ACH Distribution  ...  ACH Distribution  Check Reissue
# tax_code_1                       7  ...                 2             11
# tax_code_2                    <NA>  ...              <NA>           <NA>
#
#                           60765               60769             60902  \
# plan_id                219MBDII            219MBDII           138PLAT
# ssn                   170662072           170662072         173685304
# participant_name   Megan Garner        Megan Garner    JOHN IANNACONE
# state                        PA                  PA                PA
# gross_amt                5000.0              5000.0            1500.0
# fed_taxable_amt             0.0                 0.0            1500.0
# txn_date             2025-07-25          2025-07-02        2025-11-06
# txn_method        Check Reissue  Check Distribution  ACH Distribution
# tax_code_1                   11                  11                 1
# tax_code_2                 <NA>                <NA>              <NA>
#
#                              60904             60905               60914  \
# plan_id                    138PLAT           138PLAT           177PLAT-R
# ssn                      173685304         173685304           161649871
# participant_name    JOHN IANNACONE    JOHN IANNACONE       Mark Dempster
# state                           PA                PA                  PA
# gross_amt                   1500.0            1500.0               27.68
# fed_taxable_amt             1500.0            1500.0                 0.0
# txn_date                2025-10-08        2025-09-10          2025-11-12
# txn_method        ACH Distribution  ACH Distribution  Check Distribution
# tax_code_1                       1                 7                   H
# tax_code_2                    <NA>              <NA>                <NA>
#
#                                60919               60955
# plan_id                    177PLAT-R           3025MBD-R
# ssn                        161649871           168745980
# participant_name       Mark Dempster        Paul Russick
# state                             PA                  PA
# gross_amt                   30309.62             4345.05
# fed_taxable_amt                  0.0                 0.0
# txn_date                  2025-10-07          2025-10-15
# txn_method        Check Distribution  Check Distribution
# tax_code_1                         H                   H
# tax_code_2                      <NA>                <NA>
#
# [10 rows x 6980 columns]

# %% [markdown]
# - At this point we can use the funtion .drop_duplicates() to remove duplicate rows -> actually removing duplicate original columns.
#     - After duplicate function is applied we can use transpose again to go back to original rows-columns DataFrame format,
#       now without duplicate columns.

# %%
# In transpose DataFrame use .drop_duplicates() and transpose again to go back to
#   original rows-columns DataFrame format.
matrix_clean_no_dup_cols = t_matrix_clean.drop_duplicates().T

matrix_clean_no_dup_cols.head(10)
# Out:
#           plan_id        ssn participant_name state gross_amt fed_taxable_amt  \
# 29932  IRA127PLAT  194362032     Sandra Marsh    PA    153.22          153.22
# 29933  IRA127PLAT  209501562  Kathryn Clausen    PA     200.0           200.0
# 29934  IRA127PLAT  194362032     Sandra Marsh    PA    153.22          153.22
# 29936  IRA127PLAT  209501562  Kathryn Clausen    PA     200.0           200.0
# 29938  IRA127PLAT  194362032     Sandra Marsh    PA    153.22          153.22
# 29939  IRA127PLAT  209501562  Kathryn Clausen    PA     200.0           200.0
# 29941  IRA127PLAT  194362032     Sandra Marsh    PA    153.22          153.22
# 29942  IRA127PLAT  209501562  Kathryn Clausen    PA     200.0           200.0
# 29944  IRA127PLAT  194362032     Sandra Marsh    PA    153.22          153.22
# 29945  IRA127PLAT  209501562  Kathryn Clausen    PA     200.0           200.0
#
#          txn_date        txn_method tax_code_1 tax_code_2 tax_form dist_type  \
# 29932  2025-11-04  ACH Distribution          7       <NA>   1099-R       nan
# 29933  2025-11-04  ACH Distribution          7       <NA>   1099-R       nan
# 29934  2025-10-16  ACH Distribution          7       <NA>   1099-R       nan
# 29936  2025-10-03  ACH Distribution          7       <NA>   1099-R       nan
# 29938  2025-09-03  ACH Distribution          7       <NA>   1099-R       nan
# 29939  2025-09-03  ACH Distribution          7       <NA>   1099-R       nan
# 29941  2025-08-05  ACH Distribution          7       <NA>   1099-R       nan
# 29942  2025-08-05  ACH Distribution          7       <NA>   1099-R       nan
# 29944  2025-07-03  ACH Distribution          7       <NA>   1099-R       nan
# 29945  2025-07-03  ACH Distribution          7       <NA>   1099-R       nan
#
#       roth_initial_contribution_year transaction_id matrix_account  \
# 29932                           <NA>       44178108       07P6LM3M
# 29933                           <NA>       44178107       07P6LM3M
# 29934                           <NA>       43696486       07P6LM3M
# 29936                           <NA>       43237695       07P6LM3M
# 29938                           <NA>       42348013       07P6LM3M
# 29939                           <NA>       42348012       07P6LM3M
# 29941                           <NA>       41521055       07P6LM3M
# 29942                           <NA>       41521056       07P6LM3M
# 29944                           <NA>       40587387       07P6LM3M
# 29945                           <NA>       40587386       07P6LM3M
#
#         partipant_name
# 29932     Sandra Marsh
# 29933  Kathryn Clausen
# 29934     Sandra Marsh
# 29936  Kathryn Clausen
# 29938     Sandra Marsh
# 29939  Kathryn Clausen
# 29941     Sandra Marsh
# 29942  Kathryn Clausen
# 29944     Sandra Marsh
# 29945  Kathryn Clausen
