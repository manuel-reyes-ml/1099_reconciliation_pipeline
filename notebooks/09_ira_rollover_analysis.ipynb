# %%
# Cell 1 - Tell python where to find the modules to import from

import sys
from pathlib import Path

#Path.cwd().parent depends on where you run this code from
#Path(__file__).resolve().parents[1] depends on where this file is located on disk
#
#project_root = .../1099-reconciliation-pipeline if notebook runs from the repo root or from notebooks/
cwd = Path.cwd()
project_root = cwd if (cwd / "src").exists() else cwd.parent # running from notebooks/  folder (cwd = current working directory) - .parent gets us to the folder above
sys.path.append(str(project_root)) #sys.path is a list of folders where python looks for modules
                                    # we add the project root to that list with .append

print("Project root: ", project_root)
# Out:
# Project root:  /Users/manuelreyes/Desktop/dev/projects/1099_reconciliation_pipeline

# %% [markdown]
# '--------------------------------  Engine D: Load & Run Analysis (G/H tax codes only)  --------------------------------'

# %%
# Cell 2 — Imports, Load & Clean inputs (real paths)

from src.core import load_data
from src.cleaning.clean_matrix import clean_matrix
from src.engines.ira_rollover_analysis import run_ira_rollover_analysis
from src.outputs.build_correction_file import build_correction_dataframe, write_correction_file

from src.config import RAW_DATA_DIR, USE_SAMPLE_DATA_DEFAULT, DateFilterConfig

if USE_SAMPLE_DATA_DEFAULT:
    matrix_path = None
else:
    matrix_path = RAW_DATA_DIR / "real_all_matrix_2025.xlsx"

# Optional date filtering (set to None for "All")
date_filter = None
# date_filter = DateFilterConfig(date_start="2025-07-01", date_end="2025-09-30", months=["July", "Aug"])

# Load and clean Matrix raw data
matrix_raw = load_data.load_matrix_excel(path=matrix_path)
matrix_clean = clean_matrix(matrix_raw)

print(f"Matrix Cleaned DataFrame shape: {matrix_clean.shape}")
# Out:
# Matrix Cleaned DataFrame shape: (8689, 21)
# /var/folders/_5/q9dxw26d4rl_63x79z_n9kkm0000gn/T/ipykernel_31146/3085111751.py:21: UserWarning: Matrix SSN normalization produced 11 invalid values.
#   matrix_clean = clean_matrix(matrix_raw)

# %% [markdown]
# ### Date filter options
# Use `DateFilterConfig` to limit transactions by date range and/or months. Range and months intersect.
# Set `date_filter = None` for all data. Missing/invalid dates are excluded when filters are active.
#
# Examples:
# - All data: `date_filter = None`
# - Range only: `DateFilterConfig(date_start="2025-01-01", date_end="2025-01-31")`
# - Months only: `DateFilterConfig(months=["July", 8])`
# - Range + months: `DateFilterConfig(date_start="2025-07-01", date_end="2025-09-30", months=["July", "Aug"])`

# %%
# Cell 3 — Run Engine D analysis (G/H tax codes only)

ira_matches = run_ira_rollover_analysis(matrix_clean, date_filter=date_filter)

print("Engine D rows (G/H tax codes only):", ira_matches.shape[0])
ira_matches.head(10)
# Out:
# Engine D rows (G/H tax codes only): 266
#           plan_id        ssn participant_name state  gross_amt  \
# 36461   IRA29PLAT  193361668    Robert Klemow    PA     218.92
# 36484   IRA29PLAT  161389368  Letitia Leitzel    FL      11.27
# 36521   IRA29PLAT  182601810  Thomas Richards    PA  200000.00
# 36544   IRA29PLAT  161389368  Letitia Leitzel    FL   15749.86
# 36650   IRA32PLAT  181466683      Martha Laux    PA  177377.67
# 36659   IRA32PLAT  172448354    BARBARA KUMAR    PA   96871.97
# 36668  IRA113PLAT  187569907     Paul Simpson    PA  454863.26
# 36670  IRA113PLAT  200489351      Mary Sidary    PA  398761.39
# 36672  IRA113PLAT  171400540  William Jackson    PA  282773.14
# 36681  IRA113PLAT  208448250    Debra Jackson    PA  627858.78
#
#        fed_taxable_amt    txn_date          txn_method tax_code_1 tax_code_2  \
# 36461              0.0  2025-11-04  Check Distribution          G       <NA>
# 36484              0.0  2025-10-06  Check Distribution          G       <NA>
# 36521              0.0  2025-09-02  Check Distribution          G       <NA>
# 36544              0.0  2025-07-31  Check Distribution          G       <NA>
# 36650              0.0  2025-07-28  Check Distribution          G       <NA>
# 36659              0.0  2025-06-23  Check Distribution          G       <NA>
# 36668              0.0  2025-12-19  Check Distribution          4          G
# 36670              0.0  2025-12-16  Check Distribution          G       <NA>
# 36672              0.0  2025-12-09  Check Distribution          G       <NA>
# 36681              0.0  2025-11-17  Check Distribution          G       <NA>
#
#        ... amount_valid date_valid code_1099r_valid  validation_issues  \
# 36461  ...         True       True             True                 []
# 36484  ...         True       True             True                 []
# 36521  ...         True       True             True                 []
# 36544  ...         True       True             True                 []
# 36650  ...         True       True             True                 []
# 36659  ...         True       True             True                 []
# 36668  ...         True       True             True                 []
# 36670  ...         True       True             True                 []
# 36672  ...         True       True             True                 []
# 36681  ...         True       True             True                 []
#
#                  match_status       action  suggested_tax_code_1  \
# 36461  match_needs_correction  UPDATE_1099                     0
# 36484  match_needs_correction  UPDATE_1099                     0
# 36521  match_needs_correction  UPDATE_1099                     0
# 36544  match_needs_correction  UPDATE_1099                     0
# 36650  match_needs_correction  UPDATE_1099                     0
# 36659  match_needs_correction  UPDATE_1099                     0
# 36668  match_needs_correction  UPDATE_1099                     0
# 36670  match_needs_correction  UPDATE_1099                     0
# 36672  match_needs_correction  UPDATE_1099                     0
# 36681  match_needs_correction  UPDATE_1099                     0
#
#        suggested_tax_code_2  new_tax_code  \
# 36461                  <NA>             0
# 36484                  <NA>             0
# 36521                  <NA>             0
# 36544                  <NA>             0
# 36650                  <NA>             0
# 36659                  <NA>             0
# 36668                  <NA>             0
# 36670                  <NA>             0
# 36672                  <NA>             0
# 36681                  <NA>             0
#
#                                  correction_reason
# 36461  ira_rollover_tax_form_1099r_expected_no_tax
# 36484  ira_rollover_tax_form_1099r_expected_no_tax
# 36521  ira_rollover_tax_form_1099r_expected_no_tax
# 36544  ira_rollover_tax_form_1099r_expected_no_tax
# 36650  ira_rollover_tax_form_1099r_expected_no_tax
# 36659  ira_rollover_tax_form_1099r_expected_no_tax
# 36668  ira_rollover_tax_form_1099r_expected_no_tax
# 36670  ira_rollover_tax_form_1099r_expected_no_tax
# 36672  ira_rollover_tax_form_1099r_expected_no_tax
# 36681  ira_rollover_tax_form_1099r_expected_no_tax
#
# [10 rows x 27 columns]

# %%
# Cell 4 — Match status counts

ira_matches["match_status"].value_counts(dropna=False)
# Out:
# match_status
# match_needs_correction    264
# match_needs_review          2
# Name: count, dtype: int64

# %%
# Cell 5 - match_needs_review preview

ira_matches[ira_matches["match_status"] == "match_needs_review"].head(10)
# Out:
#            plan_id        ssn     participant_name state  gross_amt  \
# 36791   IRA109PLAT  200464173     Sandra Sosnowsky    PA  175760.04
# 39337  IRA147PLATR  162684384  Christopher Hampton    PA  173704.78
#
#        fed_taxable_amt    txn_date          txn_method tax_code_1 tax_code_2  \
# 36791        175760.04  2025-08-25  Check Distribution          G       <NA>
# 39337             0.00  2025-07-03  Check Distribution       <NA>          G
#
#        ... amount_valid date_valid code_1099r_valid  \
# 36791  ...         True       True             True
# 39337  ...         True       True            False
#
#                        validation_issues        match_status       action  \
# 36791  [cross_code_g_taxable_over_10pct]  match_needs_review  INVESTIGATE
# 39337               [code_1099r_invalid]  match_needs_review  INVESTIGATE
#
#        suggested_tax_code_1  suggested_tax_code_2  new_tax_code  \
# 36791                  <NA>                  <NA>          <NA>
# 39337                  <NA>                  <NA>          <NA>
#
#                         correction_reason
# 36791  federal_taxing_method_not_rollover
# 39337       missing_federal_taxing_method
#
# [2 rows x 27 columns]

# %%
# Cell 6 — Correction file preview

corrections_df = build_correction_dataframe(ira_matches)
print("Corrections:", corrections_df.shape[0])
corrections_df.head(10)
# Out:
# Corrections: 266
#   Transaction Id Transaction Date Participant SSN Participant Name  \
# 0       41386906       2025-07-31       161389368  Letitia Leitzel
# 1       43303313       2025-10-06       161389368  Letitia Leitzel
# 2       42302481       2025-09-02       182601810  Thomas Richards
# 3       44178532       2025-11-04       193361668    Robert Klemow
# 4       40319558       2025-06-23       172448354    BARBARA KUMAR
# 5       41292023       2025-07-28       181466683      Martha Laux
# 6       42699653       2025-09-12       160467412      Larry Myers
# 7       41982024       2025-08-20       170624760  Diana Kristobek
# 8       45226226       2025-12-09       171400540  William Jackson
# 9       45608755       2025-12-19       187569907     Paul Simpson
#
#   Matrix Account Current Tax Code 1 Current Tax Code 2 New Tax Code  \
# 0       07P6LM3T                  G               <NA>            0
# 1       07P6LM3T                  G               <NA>            0
# 2       07P6LM3T                  G               <NA>            0
# 3       07P6LM3T                  G               <NA>            0
# 4       07P6LM3V                  G               <NA>            0
# 5       07P6LM3V                  G               <NA>            0
# 6       07P6LM3W                  G               <NA>            0
# 7       07P6LM3W                  G               <NA>            0
# 8       07P6LM3W                  G               <NA>            0
# 9       07P6LM3W                  4                  G            0
#
#   New Taxable Amount New First Year contrib  \
# 0               <NA>                   <NA>
# 1               <NA>                   <NA>
# 2               <NA>                   <NA>
# 3               <NA>                   <NA>
# 4               <NA>                   <NA>
# 5               <NA>                   <NA>
# 6               <NA>                   <NA>
# 7               <NA>                   <NA>
# 8               <NA>                   <NA>
# 9               <NA>                   <NA>
#
#                                         Reason       Action
# 0  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099
# 1  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099
# 2  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099
# 3  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099
# 4  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099
# 5  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099
# 6  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099
# 7  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099
# 8  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099
# 9  ira_rollover_tax_form_1099r_expected_no_tax  UPDATE_1099

# %%
# Cell 7 — Use build_correction_file module to create/write/export the 'official' correction file

# 2) Write it to Excel with an auto-generated timestamped name
output_path = write_correction_file(corrections_df, engine="ira_rollover")

# Run write_correction_file() function
output_path
# Out:
# PosixPath('/Users/manuelreyes/Desktop/dev/projects/1099_reconciliation_pipeline/reports/outputs/ira_rollover/correction_file_20260114_221815.xlsx')
